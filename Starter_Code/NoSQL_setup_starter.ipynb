# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with mongoimport --db uk_food --collection establishments --file establishments.json --jsonArray

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['Met', 'admin', 'bird_db', 'classDB', 'config', 'local', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
pprint(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('656e5ea7d51eb772b7da3b0c'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_establishment_addition = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_establishment_addition)

# %%
# Check that the new restaurant was inserted
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('656ea7773f7dc7f129e121c9'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType':'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID':1, 'BusinessType':1,'BusinessName':1}
results = establishments.find(query, fields)
for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b0c')}
# {'BusinessName': 'The Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b0f')}
# {'BusinessName': 'Mrs Knotts Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b11')}
# {'BusinessName': 'Boodles',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b12')}
# {'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b13')}
# {'BusinessName': 'The Barn',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b14')}
# {'BusinessName': 'The Halfway Hut',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b15')}
# {'BusinessName': 'Lovetocater',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b16')}
# {'BusinessName': 'The White Cliffs',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b1b')}
# {'BusinessName': "St Margaret's Bowls and Social Club",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b1e')}
# {'BusinessName': 'Boat House & Langdon',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b1f')}
# {'BusinessName': 'The Lounge Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b20')}
# {'BusinessName': 'National Trust White Cliffs',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b2a')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b2d')}
# {'BusinessName': 'Burger King',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b31')}
# {'BusinessName': 'Walmer Castle Tea Rooms',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b3c')}
# {'BusinessName': 'Table Table at Premier Inn',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b3e')}
# {'BusinessName': 'GCP Catering Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b40')}
# {'BusinessName': 'Food Outlets',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b41')}
# {'BusinessName': 'Places Leisure',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b44')}
# {'BusinessName': 'The Dover Patrol Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b45')}
# {'BusinessName': 'Port of Dover Cargo Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b4a')}
# {'BusinessName': 'The Pedaler on the Port',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b4b')}
# {'BusinessName': 'Cullins Yard',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b4d')}
# {'BusinessName': 'Dover Marina Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b4e')}
# {'BusinessName': "Mr White's English Chophouse (DMHS)",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b4f')}
# {'BusinessName': "Wheeler's Fish & Chips",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b50')}
# {'BusinessName': 'Boardwalk Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b56')}
# {'BusinessName': 'Costa Coffee, Next',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b57')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b5a')}
# {'BusinessName': 'Nandos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b5e')}
# {'BusinessName': 'Marks and Spencer Dover Simply Food',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b5f')}
# {'BusinessName': 'Kaspas',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b60')}
# {'BusinessName': 'Taco Bell',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea7d51eb772b7da3b63')}
# {'BusinessName': 'Rico Sabor',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b65')}
# {'BusinessName': 'Cinnamon Island',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b66')}
# {'BusinessName': 'German Doner Kebab',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b71')}
# {'BusinessName': 'IL RUSTICO',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b72')}
# {'BusinessName': 'Aspendos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b79')}
# {'BusinessName': 'Terrace Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b7a')}
# {'BusinessName': 'Blakes of Dover',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b7b')}
# {'BusinessName': 'Dinos Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b7e')}
# {'BusinessName': 'KFC',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b80')}
# {'BusinessName': 'Xpresso Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b81')}
# {'BusinessName': 'Sunrise Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b86')}
# {'BusinessName': 'Bluebirds',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b8e')}
# {'BusinessName': 'Happy Chef',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b8f')}
# {'BusinessName': 'THENU Convenience Store',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b92')}
# {'BusinessName': 'The Shake Shop & The Hot Dog Hut',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b96')}
# {'BusinessName': 'Chaplins',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b97')}
# {'BusinessName': 'Honey Pot Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b98')}
# {'BusinessName': 'Pizza Shack',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b9a')}
# {'BusinessName': 'The Market Square Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3b9b')}
# {'BusinessName': 'Vinoteq Wine Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ba1')}
# {'BusinessName': 'La Salle Verte',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ba8')}
# {'BusinessName': 'Cafe Melange',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ba9')}
# {'BusinessName': 'The Corner Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bad')}
# {'BusinessName': 'MFG ESSO WALMER',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bb1')}
# {'BusinessName': 'Sea Cafe Coffee Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bb7')}
# {'BusinessName': 'Tummy Station',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bb9')}
# {'BusinessName': 'Walmer Baptist Church',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bbb')}
# {'BusinessName': 'Buzz Bingo',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bbc')}
# {'BusinessName': 'The Duke Of Yorks Brewers Fayre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bbd')}
# {'BusinessName': "Jane's",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bc7')}
# {'BusinessName': 'The Haymans Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bc8')}
# {'BusinessName': 'The Beano Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bcd')}
# {'BusinessName': "Macari's",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bd0')}
# {'BusinessName': 'The Weigh Inn',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bd5')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bd7')}
# {'BusinessName': 'Brunch Cafe Limited',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bd8')}
# {'BusinessName': 'Bandstand Bakery',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bdd')}
# {'BusinessName': 'Goose on the Green',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3be3')}
# {'BusinessName': 'Dovorian',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3be5')}
# {'BusinessName': 'Bengal Spice',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3beb')}
# {'BusinessName': 'Thong Dees Thai',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bf8')}
# {'BusinessName': 'OAKLEYS',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bfa')}
# {'BusinessName': 'Doyrms Coffee Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bfb')}
# {'BusinessName': 'St.Edmonds',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3bfc')}
# {'BusinessName': 'The Academy Dover',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c08')}
# {'BusinessName': 'La Scala',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c0b')}
# {'BusinessName': 'Wellingtons',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c0c')}
# {'BusinessName': 'Fish Bar & Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c0e')}
# {'BusinessName': 'Whitecliffs Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c11')}
# {'BusinessName': 'Calcutta Port',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c1e')}
# {'BusinessName': 'Momo Hub limited',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c1f')}
# {'BusinessName': 'Pumpkin Cafe Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c24')}
# {'BusinessName': 'Zazen Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c2a')}
# {'BusinessName': 'The Courtyard Oyster Bar And Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c2c')}
# {'BusinessName': 'New Moonflower',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c2e')}
# {'BusinessName': 'Dunkerleys Hotel & Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c35')}
# {'BusinessName': 'HEY! Sushi',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c3a')}
# {'BusinessName': 'The Taphouse',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c41')}
# {'BusinessName': 'Dylan Palace',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c46')}
# {'BusinessName': "Hoody's Community Cafe",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c47')}
# {'BusinessName': 'Hoodys Community Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c48')}
# {'BusinessName': 'Hog & Bean Deli and Eatery',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c4a')}
# {'BusinessName': 'The Grapevine cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c4f')}
# {'BusinessName': 'Little Harriettes of Deal',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c52')}
# {'BusinessName': 'Cin Cin',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c54')}
# {'BusinessName': 'The Lane',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c55')}
# {'BusinessName': 'Pop Up Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c56')}
# {'BusinessName': 'Deal Beach Parlour',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c59')}
# {'BusinessName': 'Wellingtons',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c5a')}
# {'BusinessName': 'Sea View',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c5b')}
# {'BusinessName': 'Cabin Bar, The Clarendon Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c5e')}
# {'BusinessName': 'The Meatball Company',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c5f')}
# {'BusinessName': 'Dine India, The Clarendon Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c60')}
# {'BusinessName': 'Aspendos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c61')}
# {'BusinessName': 'Salentinos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c63')}
# {'BusinessName': 'Starburger Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c6a')}
# {'BusinessName': 'Kings Coffee Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c6b')}
# {'BusinessName': 'Love Drinks',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c74')}
# {'BusinessName': 'Strand Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c76')}
# {'BusinessName': 'Peckish',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c7a')}
# {'BusinessName': 'Route One',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c7b')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c7e')}
# {'BusinessName': 'M & Co',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c85')}
# {'BusinessName': 'Royal Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c87')}
# {'BusinessName': 'Smugglers Records',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c88')}
# {'BusinessName': '81 Beach Street',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c89')}
# {'BusinessName': 'Starbucks',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c8a')}
# {'BusinessName': 'McCarthy & Stone - Dover',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c8d')}
# {'BusinessName': 'Milaad Tandoori Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c91')}
# {'BusinessName': "Kerry's Bakehouse & Eatery",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c95')}
# {'BusinessName': 'Tides Leisure Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c96')}
# {'BusinessName': 'The Dining Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3c97')}
# {'BusinessName': 'Frog and Scot',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ca5')}
# {'BusinessName': 'Hope & Lane',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ca6')}
# {'BusinessName': 'Victuals & Co',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ca8')}
# {'BusinessName': 'Soul Chef Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cad')}
# {'BusinessName': 'Middle Street Fish Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cae')}
# {'BusinessName': 'The Three Compasses',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cb5')}
# {'BusinessName': 'Tea Cafe Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cb7')}
# {'BusinessName': 'Miretti Pasticceria',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cba')}
# {'BusinessName': 'Spires Bistro, The Landmark Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cbb')}
# {'BusinessName': 'Kent Museum of the Moving Image',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cc3')}
# {'BusinessName': 'Deal Town Rangers Football Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cc5')}
# {'BusinessName': 'The Daily Grind',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ccd')}
# {'BusinessName': "Welly's Coffeehouse and Bar",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cd2')}
# {'BusinessName': "Welly's Coffee House & Bar",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cd4')}
# {'BusinessName': "Sid's ice cream and donut parlour",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cd6')}
# {'BusinessName': 'Mileage',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cd9')}
# {'BusinessName': "Brenda's Kitchen",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cdc')}
# {'BusinessName': 'Trinity Church',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ce0')}
# {'BusinessName': 'Spindrift Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ce6')}
# {'BusinessName': 'Co-op',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cf1')}
# {'BusinessName': 'White Cliffs Tandoori',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3cfd')}
# {'BusinessName': 'Friendship Lunch',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d07')}
# {'BusinessName': 'Clay Pigeon Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d25')}
# {'BusinessName': "Engel's Paradise (Bistro)",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d2f')}
# {'BusinessName': 'Skylight Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d30')}
# {'BusinessName': 'One Church Dover',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d33')}
# {'BusinessName': 'The Smugglers Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d36')}
# {'BusinessName': 'Breakwater Tap House and Pizzeria',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d39')}
# {'BusinessName': "Kelly's Snacks",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d47')}
# {'BusinessName': 'Little Farthingloe Farm Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d5b')}
# {'BusinessName': 'Pit Stop Snack Bar Unit 1',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d73')}
# {'BusinessName': "Solley's Ice Cream Parlour",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d77')}
# {'BusinessName': 'Dover District Leisure Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d83')}
# {'BusinessName': 'Coombes Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d85')}
# {'BusinessName': 'St Radigunds Community Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d87')}
# {'BusinessName': 'Carls kitchen at caesar court',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d89')}
# {'BusinessName': 'The Plough Inn Beefeater',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3d98')}
# {'BusinessName': 'Dover Transport Museum',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3da4')}
# {'BusinessName': 'KFC',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3da5')}
# {'BusinessName': 'Sutton Vale Caravan Park And Country Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3daa')}
# {'BusinessName': 'Tesco Family Dining Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dae')}
# {'BusinessName': 'The Lake House Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3db1')}
# {'BusinessName': 'Crabble Corn Mill Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3db3')}
# {'BusinessName': 'The Truck Park Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3db9')}
# {'BusinessName': 'The Rock Rose',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dba')}
# {'BusinessName': 'Galliford Try Building Ltd - Beeches',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dbf')}
# {'BusinessName': 'Rajmahal',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dc2')}
# {'BusinessName': 'Boost Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dc3')}
# {'BusinessName': 'Mcdonalds Drive Thru',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dc8')}
# {'BusinessName': 'Bella Italia (Holiday Inn)',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dd2')}
# {'BusinessName': 'Leaf Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dd3')}
# {'BusinessName': 'The Lamp Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dd6')}
# {'BusinessName': 'Kearsney Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3de3')}
# {'BusinessName': 'Coombe Valley Raceway',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3de8')}
# {'BusinessName': 'Lillyroos Glamping & camping',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3de9')}
# {'BusinessName': 'K J Auctions',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dee')}
# {'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3df3')}
# {'BusinessName': 'Dr Legumes - Harbour Arm',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3dfe')}
# {'BusinessName': 'Custom Folkestone',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e02')}
# {'BusinessName': 'Barney & The Pizza',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e06')}
# {'BusinessName': "Dino's",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e07')}
# {'BusinessName': 'Harbour Coffee Company',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e16')}
# {'BusinessName': 'Putters!',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e1c')}
# {'BusinessName': 'The Lighthouse Tasting Rooms',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e1f')}
# {'BusinessName': 'Little Switzerland Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e23')}
# {'BusinessName': 'The Captains Table',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e24')}
# {'BusinessName': 'Herberts',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e27')}
# {'BusinessName': 'Rocksalt',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e28')}
# {'BusinessName': 'Pick Up Pintxos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e38')}
# {'BusinessName': 'Folklore',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e3f')}
# {'BusinessName': 'Bella Vita',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e41')}
# {'BusinessName': 'Diamond Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e47')}
# {'BusinessName': 'Touchbase Care',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e4b')}
# {'BusinessName': 'The Nook',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e4c')}
# {'BusinessName': 'Steep Street Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e4f')}
# {'BusinessName': 'El Cortador',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e51')}
# {'BusinessName': 'Big Boys Fine Burger Co',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e54')}
# {'BusinessName': 'Misused Cocktails',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e56')}
# {'BusinessName': 'Hillside Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e57')}
# {'BusinessName': 'Lucky Chip',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e58')}
# {'BusinessName': 'The Space Bar & Gallery',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e59')}
# {'BusinessName': 'Planet Earth Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e60')}
# {'BusinessName': 'Aspendos Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e62')}
# {'BusinessName': 'Sweet Rendezvous',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e63')}
# {'BusinessName': 'Eleto Chocolate Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e68')}
# {'BusinessName': 'Lubens',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e6a')}
# {'BusinessName': 'Oriental Buffet',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e6b')}
# {'BusinessName': 'Wonderland Tearoom',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e6c')}
# {'BusinessName': 'The Tearooms',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e71')}
# {'BusinessName': 'Androus Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e73')}
# {'BusinessName': 'Curry Garden',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e7c')}
# {'BusinessName': 'Djangos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e7d')}
# {'BusinessName': 'Market Square Folkestone',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e7f')}
# {'BusinessName': 'Luciano Pizzaria',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e83')}
# {'BusinessName': 'Cube Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e84')}
# {'BusinessName': 'Mcdonalds Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e87')}
# {'BusinessName': 'Kathmandu House Grilled Tandoori',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e88')}
# {'BusinessName': 'Sunshine Coffee and Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e8c')}
# {'BusinessName': 'RESTOCK',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e90')}
# {'BusinessName': 'Fireaway Pizza Folkestone',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e91')}
# {'BusinessName': 'La Princesse',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e93')}
# {'BusinessName': "Grind n' Bake",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e95')}
# {'BusinessName': 'Zen Cafe Asian Diner',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e99')}
# {'BusinessName': 'Lilys American Diner',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e9a')}
# {'BusinessName': 'Abercrombies Community Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3e9c')}
# {'BusinessName': 'The Bao Baron',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ea0')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ea2')}
# {'BusinessName': 'Starbucks',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ea6')}
# {'BusinessName': 'Caffe La Delizia',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ea7')}
# {'BusinessName': 'EK Baar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eac')}
# {'BusinessName': 'Folkestone 51',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eaf')}
# {'BusinessName': 'KFC',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eb1')}
# {'BusinessName': 'Blank Canvas Cafe Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eb9')}
# {'BusinessName': 'The Full English',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eba')}
# {'BusinessName': 'Bettys Pye & Mash',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ebc')}
# {'BusinessName': 'Burger King',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ec4')}
# {'BusinessName': 'Cafe Tulip',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ec5')}
# {'BusinessName': 'Asda Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ec6')}
# {'BusinessName': 'Le Cafe Ganmac',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ecc')}
# {'BusinessName': 'Thong-Dees',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ece')}
# {'BusinessName': 'Roccos',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ed0')}
# {'BusinessName': 'Leas Cliff Hall',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ed2')}
# {'BusinessName': 'The Little Place......Next Door',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ed8')}
# {'BusinessName': 'Laurielles Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ed9')}
# {'BusinessName': 'Bella Pizza & Pasta',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3edb')}
# {'BusinessName': 'Browns Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3edc')}
# {'BusinessName': 'Papas',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3edd')}
# {'BusinessName': 'Gourmet Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ede')}
# {'BusinessName': 'Waves Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ee1')}
# {'BusinessName': 'Annapurna',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ee6')}
# {'BusinessName': "Anna's Tearoom",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ee8')}
# {'BusinessName': 'Food For Thought',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ee9')}
# {'BusinessName': 'Three Hills Sports Park',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eeb')}
# {'BusinessName': 'Sotirios Bar & Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ef8')}
# {'BusinessName': 'Genesis',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3ef9')}
# {'BusinessName': 'The Brasserie MS',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3efc')}
# {'BusinessName': 'The Brasserie MS',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3efd')}
# {'BusinessName': 'Rosemont Restaurant & Cocktail Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3eff')}
# {'BusinessName': 'Swiss Reassurance Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f05')}
# {'BusinessName': 'The Waterfront Cafe Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f06')}
# {'BusinessName': 'The Cider Works',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f07')}
# {'BusinessName': 'Bouverie Tap',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f09')}
# {'BusinessName': 'Ali Baba Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f0b')}
# {'BusinessName': 'The Hideaway',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f0d')}
# {'BusinessName': 'Conchitas',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f0e')}
# {'BusinessName': 'The Radnor Arms',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f14')}
# {'BusinessName': 'The View Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f17')}
# {'BusinessName': 'Cocomee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f19')}
# {'BusinessName': 'Brew',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f1f')}
# {'BusinessName': 'Black Bull Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f29')}
# {'BusinessName': 'Sandwich Bay Bird Observatory',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f2c')}
# {'BusinessName': 'Bridge Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f41')}
# {'BusinessName': 'Grand Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f45')}
# {'BusinessName': 'Radnor Park Lodge',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f47')}
# {'BusinessName': 'League of Friends Coffee Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f4e')}
# {'BusinessName': 'Wards Hotel & Bistro',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f4f')}
# {'BusinessName': 'The Marquis',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f53')}
# {'BusinessName': 'Brasserie on The Bay',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f57')}
# {'BusinessName': 'Tunnels Tea Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f6b')}
# {'BusinessName': 'The Gardeners Kitchen Tea Rooms',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f73')}
# {'BusinessName': 'Sorbetto',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f76')}
# {'BusinessName': 'A La Turka',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f77')}
# {'BusinessName': 'Alexandra Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f78')}
# {'BusinessName': 'The Dog House & Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f7b')}
# {'BusinessName': 'Thai Passion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f85')}
# {'BusinessName': 'Alison Sea View Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f88')}
# {'BusinessName': 'Folkestone Sports Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f89')}
# {'BusinessName': 'Royal Harbour Ramsgate Brasserie',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f8a')}
# {'BusinessName': "Sam's Bar",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f8b')}
# {'BusinessName': 'Updown',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f8c')}
# {'BusinessName': 'Enoteca',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f8d')}
# {'BusinessName': 'Clique Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f90')}
# {'BusinessName': 'Little Ships',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f91')}
# {'BusinessName': 'Thanet Bowling Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f92')}
# {'BusinessName': 'The Glass House Tea Garden',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f93')}
# {'BusinessName': 'Travellers in Italy',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f94')}
# {'BusinessName': 'Baker Street Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3f9a')}
# {'BusinessName': 'The Blazing Donkey',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fa4')}
# {'BusinessName': 'Jah Jah',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fa7')}
# {'BusinessName': "Gerry's Coffee & Art House",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fab')}
# {'BusinessName': "Coco Latino & Clarey's Chocolates",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fac')}
# {'BusinessName': 'The Arch',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fad')}
# {'BusinessName': 'Ship Shape',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fae')}
# {'BusinessName': 'The Greek Arch',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3faf')}
# {'BusinessName': 'Archive Homestore',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fb0')}
# {'BusinessName': 'Il Tricolore',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fb2')}
# {'BusinessName': 'Ramsgate Tandoori',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fb3')}
# {'BusinessName': 'Village Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fb5')}
# {'BusinessName': 'T.L.C',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fb8')}
# {'BusinessName': 'Book Bodega',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fba')}
# {'BusinessName': 'Sunrise Cafe Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fbe')}
# {'BusinessName': 'Corbys Tearooms',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fc0')}
# {'BusinessName': 'The Home Front Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fc8')}
# {'BusinessName': 'The Galley',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5ea8d51eb772b7da3fc9')}
# {'BusinessName': 'Marc-Pierres Kitchen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4ad')}
# {'BusinessName': 'Yuva',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4b2')}
# {'BusinessName': "Boar's Head Steak House And Grill",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4b3')}
# {'BusinessName': 'Tandoori Cottage Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4bd')}
# {'BusinessName': 'Huckleberry Chicken',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4be')}
# {'BusinessName': 'Folies',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4c1')}
# {'BusinessName': 'Eat Sheaf',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4c5')}
# {'BusinessName': 'Zara Indian Dining',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4cb')}
# {'BusinessName': 'Mountbatten',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4ce')}
# {'BusinessName': 'Elder Street Cafe & Deli',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4d6')}
# {'BusinessName': 'Debden Lunch Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4d7')}
# {'BusinessName': 'Blues Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4d8')}
# {'BusinessName': 'The Doorstep Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad4e1')}
# {'BusinessName': 'Tyndalls',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad502')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad50a')}
# {'BusinessName': 'Chives Catering',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad50e')}
# {'BusinessName': 'Just at the Station',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad513')}
# {'BusinessName': 'Sewards End Village Hall',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad514')}
# {'BusinessName': 'Servest Food Company',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad515')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad517')}
# {'BusinessName': 'The Boathouse Cafe Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad51a')}
# {'BusinessName': 'River Palace Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad51c')}
# {'BusinessName': 'Rosey Lea',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad51d')}
# {'BusinessName': 'Cortland Fibron BX',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad51e')}
# {'BusinessName': 'Henry Moore Foundation Visitor Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad51f')}
# {'BusinessName': 'Copleys',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad520')}
# {'BusinessName': 'Beefeater',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad531')}
# {'BusinessName': 'Costa Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad535')}
# {'BusinessName': 'Hoddesdon Town Football Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad541')}
# {'BusinessName': 'Hi Bar Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad543')}
# {'BusinessName': 'Chase Health and Fitness',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad548')}
# {'BusinessName': 'Parklands Quendon Hall Events Venue',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad549')}
# {'BusinessName': 'Turpins Indoor Bowls Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad555')}
# {'BusinessName': 'Lord Butler Leisure Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad556')}
# {'BusinessName': 'Quinntessential Catering',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad55a')}
# {'BusinessName': "Fill's Cafe",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad55f')}
# {'BusinessName': 'Wood Street Coffee Roasters Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad561')}
# {'BusinessName': 'Hope Community Hub-Make Lunch',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad563')}
# {'BusinessName': 'Jam Hospitality Limited',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad564')}
# {'BusinessName': 'New Life Pentecostal Church',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad566')}
# {'BusinessName': 'Radhuni Indian Cuisine',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad56e')}
# {'BusinessName': 'Maltings Cafe Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad57f')}
# {'BusinessName': 'SOKA Catering & Events Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad583')}
# {'BusinessName': 'Wrights Fish & Chips',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad58d')}
# {'BusinessName': 'Deja Vu',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad58e')}
# {'BusinessName': 'Taste Of Raj',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad594')}
# {'BusinessName': 'Saffron Walden Entertainments',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad599')}
# {'BusinessName': "Fast Eddie's Community Cafe CIC (Fairycroft House)",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad59e')}
# {'BusinessName': "Libby's Coffee Shop",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5a1')}
# {'BusinessName': 'Khunnai Thai Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5a5')}
# {'BusinessName': "Hopley's Cafe",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5aa')}
# {'BusinessName': 'Debden Grange Retirement Village',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5ac')}
# {'BusinessName': 'Monday Muscles',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5ae')}
# {'BusinessName': "D'Art Waffle",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5b2')}
# {'BusinessName': "Kim's Tea And Coffee House",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5bb')}
# {'BusinessName': 'Bangkok Thai Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5be')}
# {'BusinessName': 'Dead Time Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c0')}
# {'BusinessName': 'The Court Yard (Tiptree)',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c1')}
# {'BusinessName': 'Starbucks Coffee',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c2')}
# {'BusinessName': "EM's Coffee Bar",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c5')}
# {'BusinessName': 'The Curiosity Fair',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c7')}
# {'BusinessName': 'The Saffron Suite',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c8')}
# {'BusinessName': 'The Piano',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5c9')}
# {'BusinessName': 'Bicicletta',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5cc')}
# {'BusinessName': 'Lokma (CK Saffron Ltd)',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5ce')}
# {'BusinessName': 'SW Baptist Church Lunch Club',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5cf')}
# {'BusinessName': 'Maze Cafe Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5d0')}
# {'BusinessName': 'Pashas Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5d5')}
# {'BusinessName': 'Indigo Indian Dining',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5d6')}
# {'BusinessName': 'Costa',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5d7')}
# {'BusinessName': 'Tea Amo',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5d9')}
# {'BusinessName': 'Dough & Co',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5da')}
# {'BusinessName': 'The Curious Goat',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5dc')}
# {'BusinessName': 'La Boite Ltd.',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5dd')}
# {'BusinessName': 'Gluttons',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5de')}
# {'BusinessName': 'Support 4 Sight',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5df')}
# {'BusinessName': 'Cafe Cou Cou',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5e2')}
# {'BusinessName': 'Angela Reed Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5e7')}
# {'BusinessName': 'Jade Garden',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5e8')}
# {'BusinessName': 'Mocha Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5ed')}
# {'BusinessName': 'Joseph Barnes Wines Limited',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5ef')}
# {'BusinessName': 'The Restaurant On Church Street',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5f1')}
# {'BusinessName': 'Chaters',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5f2')}
# {'BusinessName': 'St Marys C Of E Primary School',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5f7')}
# {'BusinessName': 'Saffron Hall Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5fb')}
# {'BusinessName': 'The Mogul Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad5fe')}
# {'BusinessName': 'St Marys Church',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad602')}
# {'BusinessName': 'Ananta',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad60e')}
# {'BusinessName': 'Audley End Miniature Railway Cafe & Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad613')}
# {'BusinessName': 'Audley End House \\& Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad615')}
# {'BusinessName': 'Wendens Ambo Pre School',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad616')}
# {'BusinessName': 'The Cricketers',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad61b')}
# {'BusinessName': 'Clavering Village Hall',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad61c')}
# {'BusinessName': 'Brook Cottage Riding School',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad629')}
# {'BusinessName': 'China Garden',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad633')}
# {'BusinessName': "Poppy's Tea Room",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad634')}
# {'BusinessName': 'Something Lovely Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad63c')}
# {'BusinessName': 'Sliderman',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad649')}
# {'BusinessName': 'Leapfrogs Pre-School',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad64e')}
# {'BusinessName': 'Old Swan Tea Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad653')}
# {'BusinessName': 'March Hare Tearoom',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad655')}
# {'BusinessName': 'Tortoise Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad659')}
# {'BusinessName': 'Nuthampstead Shooting Ground',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad65e')}
# {'BusinessName': 'The Barn At Alswick',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad65f')}
# {'BusinessName': 'La Vita',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('656e5eb7d51eb772b7dad66d')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('656ea7773f7dc7f129e121c9')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(new_establishment_addition, {'$set' : {'BusinessTypeID' : 1}})

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName':'Penang Flavours'}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('656ea7773f7dc7f129e121c9'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName' : 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName' : 'Dover'})

# %%
# Check if any remaining documents include Dover
pprint(establishments.count_documents({'LocalAuthorityName' : 'Dover'}))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('656e5ea8d51eb772b7da3df3'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set' : {'geocode.longitude' : {'$toDecimal' : '$geocode.longitude'}}}])
establishments.update_many({}, [{'$set' : {'geocode.latitude' : {'$toDecimal' : '$geocode.latitude'}}}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set' : {'RatingValue' : {'$toInt' : '$RatingValue'}}}])

# %%
# Check that the coordinates and rating value are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('656e5ea8d51eb772b7da3df3'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
